# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
models = ("Deepwalk", "Node2vec", "MLP", "GCN", "GraphSage", "GAT", "GIN", "SGC")
edge_func = {
    'Dot Product': (0.9754, 0.9389, 0.7586, 0.8936, 0.9415, 0.9285, 0.8912, 0.9550),
    'Hadmard Product': (0.9805, 0.9777, 0.8415, 0.8867, 0.9554, 0.9494, 0.9575, 0.9830),
    'Concat': (0.9949, 0.9971, 0.7533, 0.8389, 0.8088, 0.9051, 0.9046, 0.9355),
}

x = np.arange(len(models))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in edge_func.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('AUC')
ax.set_title('Link prediction result')
ax.set_xticks(x + width, models)
ax.legend(loc='lower left')
# ax.set_ylim(0, 1)
fig.savefig("link_prediction.png", dpi=300)

# %%
models = ("Deepwalk", "Node2vec", "MLP", "GCN", "GraphSage", "GAT", "GIN", "SGC")
acc = {
    'acc': (0.7100, 0.7040, 0.5230, 0.7940, 0.7920, 0.7940, 0.7760, 0.7800),
}

x = np.arange(len(models))  # the label locations
width = 0.25  # the width of the bars
multiplier = 1

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in acc.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Node classification result')
ax.set_xticks(x + width, models)
ax.legend(loc='upper left')
# ax.set_ylim(0, 1)
fig.savefig("node_classification.png", dpi=300)
